# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install selenium
# !pip install webdriver
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 6.2MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# 라이브러리 import
# 라이브러리 : 필요한 도구
from selenium import webdriver  # 라이브러리(모듈) 가져오라
from selenium.webdriver import ActionChains as AC
from tqdm import tqdm
from tqdm import tqdm_notebook
import re
from time import sleep
import time

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# # import sys
# # sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# %%
# 크롬창 띄우기
# gdrive_path = '/content/drive/My Drive/Colab Notebooks/Project_GANder/gankook_cuda/'

driver = webdriver.Chrome(gdrive_path + "chromedriver.exe")  # 크롬 드라이버 로드
driver.get("https://www.instagram.com/explore/tags/%EC%B0%A8%EB%9F%89%EC%9A%A9%EB%B0%A9%ED%96%A5%EC%A0%9C/?hl=ko")  # "#차량용방향제" 검색

# %%
# print(driver.page_source)

# %% [markdown]
# ## 크롤링

# %%
dict = {}                                                       # 전체 데이터를 담을 딕셔너리 생성

# %%
# 사진 클릭
CSS_tran="div.Nnq7C.weEfm"                         # 사진 버튼 정의 ("div.Nnq7C.weEfm")
tran_button = driver.find_element_by_css_selector(CSS_tran)     # 사진 버튼 찾기
AC(driver).move_to_element(tran_button).click().perform()       # 사진 버튼 클릭
time.sleep(1)

# 크롤링 시작
len_insta = 200   # 몇 개 글을 크롤링 할건지
 
for i in range(0, len_insta):    # range : 숫자가 1씩하는 함수      
    
    target_info = {}                                            # 사진별 데이터를 담을 딕셔너리 생성
    try:
        # 사진(pic) 크롤링 시작
        overlays1 = "div._2dDPU.vCf6V .FFVAD"                   # 사진창 속 사진   # "
        img = driver.find_element_by_css_selector(overlays1)    # 사진 선택
        pic = img.get_attribute('src')                          # 사진 url 크롤링 완료         
        target_info['picture'] = pic
        # print(target_info)

        # 날짜(date) 크롤링 시작
        overlays2 = "div._2dDPU.vCf6V .c-Yi7>time"                  # 날짜 지정
        datum2 = driver.find_element_by_css_selector(overlays2)     # 날짜 선택
        date = datum2.get_attribute('title')
#         get_attribute('title')                                    # 날짜 크롤링 완료
        target_info['date'] = date
        # print(target_info)                                        
        # print(datalist)                  

        # 좋아요(like) 크롤링 시작                                  
        overlays3 = ".Nm9Fw"                                        # 리뷰창 속 날짜
        datum3 = driver.find_element_by_css_selector(overlays3)     # 리뷰 선택
        like = datum3.text                                          # 좋아요 크롤링 완료
        target_info['like'] = like
        # print(target_info)        

        # 해시태그(tag) 크롤링 시작
        overlays4 = ".C7I1f.X7jCj"                                  # 태그 지정
        datum3 = driver.find_element_by_css_selector(overlays4)     # 태그 선택
        tag_raw = datum3.text        
        tags = re.findall('#[A-Za-z0-9가-힣]+', tag_raw)            # ""#OOO"만 뽑아오기(OOO: 한글,숫자,영어,_)            
        tag = ''.join(tags).replace("#"," ")                        # "#" 제거
        target_info['tag'] = tag                                
        # print(target_info)        
        
        dict[i] = target_info            # 토탈 딕셔너리로 만들기
        
        print("{0}".format(i), tag)
        
        # 다음장 클릭
        hit=0
        while hit < 1:                         # 몇 번에 한번씩 크롤링할 것인지 숫자 지정
            hit+=1
            CSS_tran2="a.HBoOv.coreSpriteRightPaginationArrow"             # 다음 버튼 정의
            tran_button2 = driver.find_element_by_css_selector(CSS_tran2)  # 다음 버튼 find
            AC(driver).move_to_element(tran_button2).click().perform()     # 다음 버튼 클릭
            time.sleep(2)
        
    except:
        # 다음장 클릭
        CSS_tran2="a.HBoOv.coreSpriteRightPaginationArrow"             # 다음 버튼 정의
        tran_button2 = driver.find_element_by_css_selector(CSS_tran2)  # 다음 버튼 find
        AC(driver).move_to_element(tran_button2).click().perform()     # 다음 버튼 클릭
        time.sleep(2)

print(dict)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-13-134ed862e9ab> in <module>()
#       1 # 사진 클릭
#       2 CSS_tran="div.Nnq7C.weEfm"                         # 사진 버튼 정의 ("div.Nnq7C.weEfm")
# ----> 3 tran_button = driver.find_element_by_css_selector(CSS_tran)     # 사진 버튼 찾기
#       4 AC(driver).move_to_element(tran_button).click().perform()       # 사진 버튼 클릭
#       5 time.sleep(1)
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.Nnq7C.weEfm"}
#   (Session info: headless chrome=87.0.4280.66)

# %%
# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')

# result_df.rename(columns={result_df.columns[0] : name}, inplace=True)

result_df
# Out:
#                                                picture          date  \
# 0    https://scontent-icn1-1.cdninstagram.com/vp/73...  2019년 7월 10일
# 1    https://scontent-icn1-1.cdninstagram.com/vp/29...  2019년 7월 10일
# 2    https://scontent-icn1-1.cdninstagram.com/vp/8f...   2019년 7월 9일
# 3    https://scontent-icn1-1.cdninstagram.com/vp/7b...  2019년 7월 10일
# 4    https://scontent-icn1-1.cdninstagram.com/vp/0a...  2019년 6월 27일
# 5    https://scontent-icn1-1.cdninstagram.com/vp/c0...  2019년 6월 25일
# 6    https://scontent-icn1-1.cdninstagram.com/vp/93...   2019년 7월 1일
# 7    https://scontent-icn1-1.cdninstagram.com/vp/7a...   2019년 7월 1일
# 8    https://scontent-icn1-1.cdninstagram.com/vp/ee...  2019년 7월 11일
# 9    https://scontent-icn1-1.cdninstagram.com/vp/fb...  2019년 7월 11일
# 10   https://scontent-icn1-1.cdninstagram.com/vp/c8...  2019년 7월 11일
# 11   https://scontent-icn1-1.cdninstagram.com/vp/dc...  2019년 7월 11일
# 12   https://scontent-icn1-1.cdninstagram.com/vp/d6...  2019년 7월 11일
# 13   https://scontent-icn1-1.cdninstagram.com/vp/84...  2019년 7월 11일
# 14   https://scontent-icn1-1.cdninstagram.com/vp/6c...  2019년 7월 11일
# 15   https://scontent-icn1-1.cdninstagram.com/vp/74...  2019년 7월 11일
# 16   https://scontent-icn1-1.cdninstagram.com/vp/68...  2019년 7월 11일
# 17   https://scontent-icn1-1.cdninstagram.com/vp/d0...  2019년 7월 11일
# 169   좋아요 18개   캔들페이지 캔들공방 공방 화명동공방 석고방향제 원데이클래스 차량용방향제 답례품 돌...
# 170   좋아요 26개   디퓨저 차량용 꽃 실내방향제 차량용방향제 인테리어 이벤트 룸스프레이 방향제 리그램...
# 171  좋아요 113개   스누피석고방향제 찰리브라운석고방향제 석고방향제 차량용방향제 방향제 캔들 향초 소이...
# 172  좋아요 105개   우드스탁 스누피 찰리브라운 석고방향제 차량용방향제 방향제 캔들 향초 소이캔들 디퓨...
# 173  좋아요 104개   짱구 짱구석고방향제 석고방향제 차량용방향제 방향제 캔들 향초 소이캔들 디퓨저 페브...
# 174   좋아요 12개                                   미니 하트 dahoosmell
# 175   좋아요 41개
# 176  좋아요 116개                                              복숭아캔들
# 177   좋아요 31개                                                 선율
# 178   좋아요 37개                                 호빵맨 식빵맨 석고방향제 차방향제
# 179   좋아요 48개                      프라간테 프라간테샵 별목걸이곰돌이방향제 귀여운차방향제
# 180    좋아요 4개   차량용방향제 아로마푸딩 아로마푸딩방향제 사진고르기힘듬 그치만 넘나예쁜것 누구시끼야...
# 181   좋아요 27개
# 182   좋아요 11개
# 184   좋아요 53개
# 185   좋아요 22개
# 186   좋아요 47개
# 187   좋아요 21개
# 188   좋아요 73개   심스캔들 석고방향제 방향제 비숑 푸들 말티즈 차량용방향제 프렌치불독 슈나우저 시츄...
# 189   좋아요 16개   감천문화마을체험관 부산여행 비누꽃 미니화환 꽃바구니 비누꽃플로리스트 어버이날선물 ...
# 190   좋아요 63개   일상 일상스타그램 일상소통 일상그램 소통 소통그램 데일리 데일리그램 언더스코어방향...
# 191   좋아요 21개
# 192   좋아요 21개   제이드포레 까메오석고방향제 석고방향제 수강생작품 부산공방 공방 홈인테리어 방향제 ...
# 193   좋아요 34개   전주 전자담배 전주전자담배 신시가지 전주신시가지 롤로 베이핑 폐호흡액상 입호흡액상...
# 194   좋아요 80개   토이스토리 포키 DM 카톡 플친 수제몰드 토이스토리포키 핸드메이드 방향제 석고방향...
# 195   좋아요 11개                                 러브 찰리루시 dahoosmell
# 196   좋아요 73개   포항꽃을담다 포항디퓨져 포항프리저브드플라워 플라워액자 차량용방향제 돌잔치답례품 유...
# 197   좋아요 41개   비커캔들 티트리캔들 유칼립투스캔들 울산 도이캔들하우스 석고방향제 차량용석고방향제 ...
# 198   좋아요 22개   불독석고방향제 댕댕이석고 차량용방향제 석고오너먼트 인테리어소품 방향제 산본석고방향...
# 199   좋아요 61개   석고방향제 콩고야석고방향제 차량용방향제 주차번호판 토이스토리 우디석고방향제 버즈석...
#
# [195 rows x 4 columns]

# %%
n = result_df['picture'].count()
n
# Out:
# 195

# %%
result_df.to_csv("data/car_perfume({0}).csv".format(n), encoding='euc-kr')

# %%
num_pic = len(result_df['picture'])
num_pic
# Out:
# 195

# %%
# 이미지들 image 폴더에 다운받기
import urllib.request

for i in range(0, 50):
    try:
        index=result_df['picture'][i]
        urllib.request.urlretrieve(index, "image/{0}_{1}.jpg".format(date, i))        
    except:
        pass

# %% [markdown]
# 끝
